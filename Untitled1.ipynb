# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
rot = [0,0,0]
roots = [1.246098386555812, 3.141592653589794, 5.037086920623774]
df
# Out:
#            x     k
# 0    -1000.0    22
# 1     -999.0   650
# 2     -998.0  2280
# 3     -997.0  1099
# 4     -996.0    23
# ...      ...   ...
# 1996   996.0    58
# 1997   997.0   523
# 1998   998.0   250
# 1999   999.0    45
# 2000  1000.0    25
#
# [2001 rows x 2 columns]

# %%
# plt.xlim(-1,10)
# plt.ylim(1,20)
plt.plot(df['x'], df['k'], "o")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x.head()
#
# AttributeError: '_iLocIndexer' object has no attribute 'head'

# %%
df[df['k'].isnan()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23016\347234764.py in ?()
# ----> 1 df[df['k'].isnan()]
#
# ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isnan'
