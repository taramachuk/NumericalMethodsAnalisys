# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('plik.csv',names=["x", "y"])
rot = [0,0,0]
roots = [1.246098386555812, 3.141592653589794, 5.037086920623774]
df
# Out:
#         x    y
# 0   -10.0  372
# 1    -9.9  274
# 2    -9.8   57
# 3    -9.7   24
# 4    -9.6   10
# ..    ...  ...
# 196   9.6  299
# 197   9.7   10
# 198   9.8   11
# 199   9.9    6
# 200  10.0   20
#
# [201 rows x 2 columns]

# %%
plt.xlim(-1,10)
plt.ylim(1,20)
plt.plot(df['x'], df['y'], "o")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x.head()
#
# AttributeError: '_iLocIndexer' object has no attribute 'head'
